# %%
from qiskit.circuit.random import random_circuit
from qiskit.test.mock import FakeCasablanca
from qiskit.converters import circuit_to_dag 
import warnings

warnings.filterwarnings("ignore")
# %reload_ext autoreload
# %autoreload 0

# %%
backend = FakeCasablanca()
circ = random_circuit(5, 2, measure = True)
dag = circuit_to_dag(circ)

# %%
circ.draw('mpl')

# %%
from qiskit_trebugger import Debugger

# %%
db = Debugger()
db.debug(circ, backend, optimization_level = 3, coupling_map = [[0,1],[1,2],[2,3],[3,4]] , routing_method = 'sabre')
# Out:
# TimelineView(children=(HTML(value='\n        <style>\n        .title h1 { font-size: 45px; font-weight: bold; …
