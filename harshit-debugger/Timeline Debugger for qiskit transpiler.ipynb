# %% [markdown]
# # Qiskit's Transpiler Timeline Debugger - Harshit Gupta
#
# This is a POC for building a Qiskit transpiler debugger using Jupyter Widgets.

# %%
from trebugger import TreBugger
import warnings
import time
from qiskit import QuantumCircuit
from qiskit.circuit.random import random_circuit
from qiskit.test.mock import FakeCasablanca
from qiskit import transpile
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Circuit Test

# %%
rc = random_circuit(num_qubits=5, depth=10)
casb = FakeCasablanca()
rc.draw('mpl')

# %%
trb = TreBugger()

# %%
trb.debug(rc, casb, 1, "advanced")

# %%
trb.debug(rc, casb, 1, "basic", initial_layout = [0,1,2,3,4], layout_method = 'sabre')
